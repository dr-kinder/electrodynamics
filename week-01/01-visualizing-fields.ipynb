# %% [markdown]
# # Six Views of a Point Charge
#
# One of the challenges of electrodynamics is developing an intuition for potentials and fields.  What is a field?  What does it *look* like?
#
# We can answer the first question with a formal definition.  A ***field*** is a mathematical object that assigns a quantity to every point in space.  If the quantity is just a number, we call the object a ***scalar field***.  If the quantity is a vector, we call the object a ***vector field***.
#
# It is hard to say what a field "looks like".  What does temperature look like?  What does gravity look like?  Even if we can't see the quantity in question, we have many ways to represent it.  This problem will introduce you to some useful Python functions as we explore the potentials and electric fields of electric charges.

# %% [markdown]
# ## Point Charge
#
# The electrostatic potential of a point charge is
# $$V(\vec{r}) = \dfrac{kq}{r}$$
#
# The electric field of a point charge is
# $$\vec{E}(\vec{r}) = \dfrac{kq}{r^2} \hat{r}$$
#
# The following Python ***functions*** will compute the potential and electric field of a point charge.

# %%
# Get access to useful functions.
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
# Define functions to calculate fields.
def coordinates(charge=1, location=(0,0,0), box_size=5, grid_points=201, epsilon=1e-6):
    s = np.linspace(-box_size, box_size, grid_points)
    X,Y,Z = np.meshgrid(s,s,s, indexing='ij')
    
    return X, Y, Z

def potential(charge=1, location=(0,0,0), box_size=5, grid_points=201, epsilon=1e-6):
    x0, y0, z0 = location
    q = charge

    s = np.linspace(-box_size, box_size, grid_points)
    X,Y,Z = np.meshgrid(s,s,s, indexing='ij')
    R = np.sqrt((X-x0)**2 + (Y-y0)**2 + (Z-z0)**2 + epsilon**2)
    V = q/R
    
    return V

def field(charge=1, location=(0,0,0), box_size=5, grid_points=201, epsilon=1e-6):
    x0, y0, z0 = location
    q = charge

    s = np.linspace(-box_size, box_size, grid_points)
    X,Y,Z = np.meshgrid(s,s,s, indexing='ij')
    R = np.sqrt((X-x0)**2 + (Y-y0)**2 + (Z-z0)**2 + epsilon**2)
    Ex = q*(X-x0)/R**3
    Ey = q*(Y-y0)/R**3
    Ez = q*(Z-z0)/R**3
    
    return Ex, Ey, Ez

# %%
X, Y, Z = coordinates()
V = potential()
Ex, Ey, Ez = field()

# %% [markdown]
# Now that we have a scalar field and a vector field, let's look at them!

# %% [markdown]
# ### 1. 1D Slices of Potential
#
# The following code will plot the potential along three lines through a point you specify: one line parallel to the x-axis, one parallel to the y-axis, and one parallel to the z-axis.

# %%
# Choose coordinate indices for slices.
x0 = 200
y0 = 200
z0 = 200

x_val = X[x0,y0,z0]
y_val = Y[x0,y0,z0]
z_val = Z[x0,y0,z0]

print("The slices are taken through (x0,y0,z0) = (%g, %g, %g)." % (x_val, y_val, z_val))

# Create a figure and plot the slices.
fig, ax = plt.subplots(3, dpi=200)

# Plot V(x,y0,z0)
x = X[:,y0,z0]
v1 = V[:,y0,z0]
ax[0].plot(x,v1)
ax[0].set_title(r"$V(x,y_0,z_0)$")

# Plot V(x0,y,z0)
y = Y[x0,:,z0]
v2 = V[x0,:,z0]
ax[1].plot(y,v2)
ax[1].set_title(r"$V(x_0,y,z_0)$")

# Plot V(x0,y0,z)
z = Z[x0,y0,:]
v3 = V[x0,y0,:]
ax[2].plot(z,v3)
ax[2].set_title(r"$V(x_0,y_0,z)$")


fig.tight_layout()
# Out:
# The slices are taken through (x0,y0,z0) = (5, 5, 5).

# %% [markdown]
# Change the values of `x0`, `y0`, and `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the potential reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# For any given position around the charge, the potential is the same for the x, y, and z axis. The only factor which determines the potential at a given point is the distance from the center charge. That is that the position at which the potential is measured at can change as long as the distance stays the same. The shape of the graphs get steeper the closer the slice is taken to the center charge because the difference in potential is so great between the center of the graph and further positions. The limitations of these graphs are that they can only show single axes at a single distance at a time.

# %% [markdown]
# ### 2. 2D Slices of Potential
#
# The cell below will plot a 2D slice of the potential through a height that you specify.
#
# It will display a surface plot and a heatmap.

# %%
# Choose z-coordinate index for slices.
z0 = 200
z_val = Z[x0,y0,z0]

print("The slice is taken through z0 = %g." % z_val)

# Get slice
x = X[:,:,z0]
y = Y[:,:,z0]
v = V[:,:,z0]

# Create a surface plot.
fig = plt.figure(dpi=200)
ax1 = fig.add_subplot(projection='3d')
ax1.plot_surface(x,y,v, cmap='jet', antialiased=False, linewidth=0)
ax1.set_title(r"$V(x,y,z_0)$")

# Heatmap
fig, ax2 = plt.subplots(dpi=200)
image = ax2.pcolormesh(x,y,v, shading='gouraud', cmap='jet')
plt.colorbar(image, use_gridspec=True)
ax2.axis('scaled')
# Out:
# The slice is taken through z0 = 5.
# (-5.0, 5.0, -5.0, 5.0)

# %% [markdown]
# Change the value of `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the potential reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# As could have been predicted, as the z0 ceiling is increased, the maximum potential shown on the graph decreases. This is because the slice being measured gets further away from the charge source and the magnitude of the potential decreases. The shape of the curve gets steeper the closer the graph gets due to the diffenece between the potential in the center and towards the sides getting larger. The limitations of this simulation are the fact that you can only change the z axis for the slices instead of being able to turn the simulation in a different axis.

# %% [markdown]
# ### 3. 1D Slices of Electric Field
#
# The following code will plot the components of the electric field along three lines through a point you specify: one line parallel to the x-axis, one parallel to the y-axis, and one parallel to the z-axis.

# %%
# Choose coordinate indices for slices.
x0 = 150
y0 = 150
z0 = 150


x_val = X[x0,y0,z0]
y_val = Y[x0,y0,z0]
z_val = Z[x0,y0,z0]

print("The slices are taken through (x0,y0,z0) = (%g, %g, %g)." % (x_val, y_val, z_val))

# Create a figure and plot the slices.
fig, ax = plt.subplots(3,3, dpi=200)

# Plot components of E(x,y0,z0)
x = X[:,y0,z0]
y = Y[x0,:,z0]
z = Z[x0,y0,:]


Ex1 = Ex[:,y0,z0]
ax[0,0].plot(x,Ex1)
ax[0,0].set_ylabel(r"$E_x$")

Ey1 = Ey[:,y0,z0]
ax[1,0].plot(x,Ey1)
ax[1,0].set_ylabel(r"$E_y$")

Ez1 = Ez[:,y0,z0]
ax[2,0].plot(x,Ez1)
ax[2,0].set_ylabel(r"$E_z$")
ax[2,0].set_xlabel('x')


Ex2 = Ex[x0,:,z0]
ax[0,1].plot(y,Ex2)

Ey2 = Ey[x0,:,z0]
ax[1,1].plot(y,Ey2)

Ez2 = Ez[x0,:,z0]
ax[2,1].plot(y,Ez2)
ax[2,1].set_xlabel('y')


Ex3 = Ex[x0,y0,:]
ax[0,2].plot(z,Ex3)

Ey3 = Ey[x0,y0,:]
ax[1,2].plot(z,Ey3)

Ez3 = Ez[:,y0,z0]
ax[2,2].plot(z,Ez3)
ax[2,2].set_xlabel('z')

fig.tight_layout()
# Out:
# The slices are taken through (x0,y0,z0) = (2.5, 2.5, 2.5).

# %% [markdown]
# Change the values of `x0`, `y0`, and `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the electric field reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# At the origin, the field only points in the x and y directions and its magnitude is very large. The shape of the graph is a sort of wave where on the negaive side the field has a strong negative peak, and on the positive side the field has a strong positive peak. The other components of the field are zero. As the point is moved away, a positive peak develops in the y and z directions of the x axis measurement, and similarly in the z and x axis in the y zxis measurement. The z axis measurement always maintains a positive peak which degrades with the distance away from the origin. The issue with this diagram is that the graphs make a very unintuative picture of the magnitude of the field.

# %% [markdown]
# ### 4. 2D Slices of Electric Field
#
# The cell below will plot a 2D slice of the components of the electric field through a height that you specify.
#
# It will display a surface plot and a heatmap of each component.

# %%
# Choose z-coordinate index for slices.
z0 = 200
z_val = Z[x0,y0,z0]

print("The slice is taken through z0 = %g." % z_val)

# Get slices
x = X[:,:,z0]
y = Y[:,:,z0]
ex = Ex[:,:,z0]
ey = Ey[:,:,z0]
ez = Ez[:,:,z0]

# Create a surface plots.
fig = plt.figure(dpi=200)

ax = fig.add_subplot(2,3,1, projection='3d')
ax.plot_surface(x,y,ex, cmap='jet', antialiased=False, linewidth=0)
ax.set_title(r"$E_x(x,y,z_0)$")

ax = fig.add_subplot(2,3,2, projection='3d')
ax.plot_surface(x,y,ey, cmap='jet', antialiased=False, linewidth=0)
ax.set_title(r"$E_y(x,y,z_0)$")

ax = fig.add_subplot(2,3,3, projection='3d')
ax.plot_surface(x,y,ez, cmap='jet', antialiased=False, linewidth=0)
ax.set_title(r"$E_z(x,y,z_0)$")

# Heatmaps
ax = fig.add_subplot(2,3,4)
image = ax.pcolormesh(x,y,ex, shading='gouraud', cmap='jet')
ax.axis('scaled')

ax = fig.add_subplot(2,3,5)
image = ax.pcolormesh(x,y,ey, shading='gouraud', cmap='jet')
ax.axis('scaled')

ax = fig.add_subplot(2,3,6)
image = ax.pcolormesh(x,y,ez, shading='gouraud', cmap='jet')
ax.axis('scaled')

fig.tight_layout()

# image = ax.pcolormesh(x,y,v, shading='gouraud', cmap='jet')
# plt.colorbar(image, use_gridspec=True)
# ax.axis('scaled')
# Out:
# The slice is taken through z0 = 5.

# %% [markdown]
# Change the value of `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the electric field reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# These graphs show a plane on a given component axis at different points on the z axis which illustrates the electric field magnitude due to the charge in the center. These graphs tell a similar story to the 1D graphs, except the slices extend in two directions instead of one. One thing to note is that the z axis consistantly has a pointy shape, while the x and y axis planes have a positive and negative peak. This tells us that the electric field is not the same polarity in both directions around the charge. The limitation of this model is that it is somewhat difficult to determine the directionality of the field with this 2D model.

# %% [markdown]
# ### 5. Quiver Plots of Electric Field
#
# The cell below will create a 3D "quiver plot" of the electric field and a 2D quiver plot of a slice through the electric field.

# %%
# Uncomment the last line for interactive plots.

# %matplotlib inline
# %matplotlib notebook

# %%
# Create a quiver plot.
# Use a coarser grid.
stride = 40
x = X[::stride,::stride,::stride].copy()
y = Y[::stride,::stride,::stride].copy()
z = Z[::stride,::stride,::stride].copy()
ex = Ex[::stride,::stride,::stride].copy()
ey = Ey[::stride,::stride,::stride].copy()
ez = Ez[::stride,::stride,::stride].copy()

# Set max length to improve visibility in plot.
ecut = 1
ex[ex>ecut] = ecut
ey[ey>ecut] = ecut
ez[ez>ecut] = ecut
ex[ex<-ecut] = -ecut
ey[ey<-ecut] = -ecut
ez[ez<-ecut] = -ecut

fig = plt.figure(dpi=200)
ax = fig.add_subplot(projection='3d')
ax.quiver3D(x,y,z,ex,ey,ez, pivot='middle', length=5, linewidth=0.5, color='red')
ax.set_title(r"$\vec{E}(\vec{R})$")

# Make a 2D plot of a slice of the field.
z0 = 130
z_val = Z[0,0,z0]

# Use a coarser grid.
stride = 25
x = X[::stride,::stride,z0].copy()
y = Y[::stride,::stride,z0].copy()
ex = Ex[::stride,::stride,z0].copy()
ey = Ey[::stride,::stride,z0].copy()

# Set max length to improve visibility in plot.
ex[ex>ecut] = ecut
ey[ey>ecut] = ecut
ex[ex<-ecut] = -ecut
ey[ey<-ecut] = -ecut

fig = plt.figure(dpi=200)
ax = fig.add_subplot()
ax.quiver(x,y,ex,ey, pivot='middle', scale=0.8, linewidth=0.5, color='red')
ax.set_title("Projection of field onto plane at z=%g" % z_val)
ax.axis("scaled")
# Out:
# (-5.5, 5.5, -5.5, 5.5)

# %% [markdown]
# Change the values of `ecut` and `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the electric field reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# This graph shows us that Gauss's law in its differential form is correct. This is due to the fact that the electric field propogates in all directions but has no curl. The equation which describes the electric field at a given radius from a charge is correct due to the fact that the electric field magnitude gets larger closer to the charge. The limitation of this model is that there is a small space in which the charge is shown

# %% [markdown]
# ### 6. Streamlines of the Electric Field
#
# The cell below will draw three dimensional "field lines" of the electric field.

# %%
# Make a 2D plot of a slice of the field.
z0 = 200
z_val = Z[0,0,z0]

# Use a coarser grid.
stride = 1
x = X[::stride,::stride,z0].copy().T
y = Y[::stride,::stride,z0].copy().T
ex = Ex[::stride,::stride,z0].copy().T
ey = Ey[::stride,::stride,z0].copy().T

# Set max length to improve visibility in plot.
ecut = 1
ex[ex>ecut] = ecut
ey[ey>ecut] = ecut
ex[ex<-ecut] = -ecut
ey[ey<-ecut] = -ecut

fig = plt.figure(dpi=200)
ax = fig.add_subplot()
ax.streamplot(x,y,ex,ey, linewidth=0.5, density=1.5)
ax.set_title("Projection of field onto plane at z=%g" % z_val)
ax.axis("scaled")
# Out:
# (-5.0, 5.0, -5.0, 5.0)

# %% [markdown]
# Change the values of `ecut` and `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the electric field reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# This once again shows that Gauss's law in its differential form is correct. If there was another charge or a dipole in the mix, these field lines would have some curl to them instead of eminating straight out from the point charge. This diagram does not show magnitude of electric field, so regardless of slice z-axis position, the lines are pretty much the same. The limitation of this graph is that magnitude is not considered for the field.

# %% [markdown]
# ## Reflection
#
# All of these plots are representations of the same underlying physical entity: the electromagnetic field of a single point charge.  Which did you find most useful?  Confusing?  Can you think of another way to represent a three-dimensional electric field or scalar field?
#
# ***Type your response in the box below.***

# %% [markdown]
# The most confusing plots were the 1D plots of the electric field. I was trying to wrap my head around why they were shaped the way they were, why they had both positive and negative peaks. The most useful graph was the 3D quiver plot, since it gave both maginute and direction of the field. Putting the potential graphs and the field graphs together, the equation describing the potential from the electric field makes sense. The potential is equavalent to the gradient of the electric field, which makes sense why it was a solid peak in the center of the graph, since that was where the point charge was. Another way to represent a field would be to use field lines in a 3D space. They would extend infinitely out into space since the field lines (unlike vectors) have no magnitude. This experiment could be improved by placing another charge somewhere in the diagram to see how the vectors change.
